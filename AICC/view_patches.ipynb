# %%
import matplotlib.pyplot as plt
import glob
import numpy as np

# %%
path = '/workspace/data/cv_methods/dsmil-wsi/WSI_old/bcc_augumented/pyramid/0/BCC34 (2)_0'
path = '/workspace/data/cv_methods/dsmil-wsi/WSI/bcc/pyramid/0/BCC34 (2)_0'
all_image = glob.glob(path + '/*.jpeg')

# %%
fig = plt.figure(figsize=(15, 15))
columns = 10
rows    = 10
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(plt.imread(all_image[i]))
    plt.axis('off')
plt.savefig('figures/no_augemnetation_0.png',bbox_inches='tight', pad_inches=0)

# %%
plt.show()
