# %%
import matplotlib.pyplot as plt
import glob
import numpy as np

# %%
path = '/workspace/data/cv_methods/tmi2022/WSI/BCC17 (4)_0_files/20.0/'
all_image = glob.glob(path + '/*')

# %%
w = 10
h = 10
fig = plt.figure(figsize=(10, 10))
columns = 20
rows    = 20
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(plt.imread(all_image[i]))
    plt.axis('off')
plt.show()

# %%
w = 10
h = 10
fig = plt.figure(figsize=(10, 10))
columns = 20
rows    = 20
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(plt.imread(all_image[i]))
    plt.axis('off')
plt.show()

# %%
path = '/workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/'
all_image = glob.glob(path + '/*')
w = 10
h = 10
fig = plt.figure(figsize=(10, 10))
columns = 20
rows    = 20
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(plt.imread(all_image[i]))
    plt.axis('off')
plt.savefig('orginal grid.jpeg')
plt.show()

# %%
path = '/workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/'
all_image = glob.glob(path + '/*')
w = 10
h = 10
fig = plt.figure(figsize=(10, 10))
columns = 20
rows    = 20
for i in range(1, columns*rows +1):
    img = plt.imread(all_image[i])
    if np.mean(img) > 100:
        fig.add_subplot(rows, columns, i)
        plt.imshow(img)
    else:
        # print(all_image[i])
        pass
    plt.axis('off')
plt.savefig('With out black.jpeg')
plt.show()
# Out:
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/14_45.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/16_45.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/17_45.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/15_45.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/17_46.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/14_46.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/16_46.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/12_46.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/9_46.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/8_46.jpeg
# /workspace/data/cv_methods/tmi2022/WSI_orginal/WSI/BCC444 (4)_0_files/20.0/11_46.jpeg
# ...

# %%
len(glob.glob('/workspace/data/bcc-projekt-digital/bcc/*/*'))
# Out:
# 507

# %%
img = plt.imread('/workspace/data/cv_methods/tmi2022/WSI/BCC461 (3)_0_files/20.0/21_1.jpeg')
plt.hist(img[:,:,2].ravel())
plt.imshow(img)

# %%
path = '/workspace/data/cv_methods/tmi2022/WSI/BCC43 (3)_1a_files/20.0/'
all_image = glob.glob(path + '/*')
w = 10
h = 10
fig = plt.figure(figsize=(10, 10))
columns = 20
rows    = 20
for i in range(1, columns*rows +1):
    img = plt.imread(all_image[i])
    if np.mean(img) >100:
        fig.add_subplot(rows, columns, i)
        plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
path = '/workspace/data/cv_methods/tmi2022/WSI/BCC454 (6)_2_files/20.0/'
img = plt.imread(path + '11_95.jpeg')
plt.imshow(img)

# %%
path = '/workspace/data/cv_methods/tmi2022/WSI/BCC454 (6)_2_files/20.0/'
img = plt.imread(path + '91_80.jpeg')
plt.imshow(img)

# %%
fig = plt.figure(figsize=(10,5))
for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.hist((img[:,:,i]).ravel(), bins=20)
    
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.hist((img[:,:,i]).ravel(), bins=20)
    print(np.mean(img[:,:,i]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       2 for i in range(3):
#       3     plt.subplot(1, 3, i+1)
# ----> 4     plt.hist((img[:,:,i]).ravel(), bins=20)
#       5     print(np.mean(img[:,:,i]))
#       6 plt.show()
#
# NameError: name 'img' is not defined
